# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', None)

# %%
xls = pd.ExcelFile('/Users/s_pasiukevich/Library/Containers/com.microsoft.Excel/Data/Downloads/Fin_Report 2017_v_17_11_17.xlsx')

# %%
sheet_names = xls.sheet_names
sheet_names
# Out:
# ['2017',
#  'Сводная',
#  'каталог',
#  'HRMS12',
#  'HRMS11',
#  'HRMS 10',
#  'HRMS 09',
#  'HRMS 08',
#  'HRMS 07',
#  'HRMS 06',
#  'HRMS 05',
#  'HRMS 03-04',
#  'Sheet1',
#  'HRMS']

# %%
df = pd.read_excel(xls, "Сводная")
df.head(10)
# Out:
#                  Office                      (All)      Unnamed: 2  \
# 0                Period                      (All)             NaN
# 1                   NaN                        NaN             NaN
# 2            Row Labels  Sum of Number of Attendee  Average of WGU
# 3  Books/ Subscriptions                          1             NaN
# 4     External Training                        701        4.690698
# 5          Facilitation                        179        4.433333
# 6      Leading by HEART                        724           4.851
# 7                  Meal                        NaN             NaN
# 8           Open Events                         91             NaN
# 9                 Other                          0             NaN
#
#                     Unnamed: 3          Unnamed: 4        Unnamed: 5  \
# 0                          NaN                 NaN               NaN
# 1                          NaN                 NaN               NaN
# ...

# %%
# read all sheets and extract first 5 rows, 3 columns
for tab in sheet_names:
    print('#  ' + tab + '   #')
    df = pd.read_excel(xls, tab)
    print(df.iloc[:2, :3])
# Out:
# #  2017   #
# /Users/s_pasiukevich/PycharmProjects/pythonProject4/venv/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#   Column1   Period       Beginning Date
# 0      Q1  January  2017-01-12 00:00:00
# 1      Q1  January  2017-01-12 00:00:00
# #  Сводная   #
#    Office  (All) Unnamed: 2
# 0  Period  (All)        NaN
# 1     NaN    NaN        NaN
# #  каталог   #
#    Unnamed: 0  Unnamed: 1        Type of event
# 0         NaN         NaN     Leading by HEART
# 1         NaN         NaN  Management Bootcamp
# #  HRMS12   #
#   Exported to Excel on 19 December 2017 (W. Europe Standard Time +01:00)  \
# 0                                                                    NaN
# 1                                                           Display Name
#
#   Unnamed: 1     Unnamed: 2
# 0        NaN            NaN
# 1     Office  Full org path
# #  HRMS11   #
# ...

# %%
df = pd.read_excel(xls, "HRMS 10")
df.head(12)
# Out:
#    Exported to Excel on 24 October 2017 (W. Europe Daylight Time +02:00)  \
# 0                                                                    NaN
# 1                                                           Display Name
# 2                                                    Ekaterina Dyachenko
# 3                                                     Aleksey Klyuchikov
# 4                                                        Guido Eickmeyer
# 5                                                        Bogdan Shmorgun
# 6                                                      Darya Poshtarenko
# 7                                                       Denis Gritsfeldt
# 8                                                     Denis Kozhuschenko
# 9                                                        Andrei Klimenko
# 10                                                        Andrei Kosarev
# 11                                                        Andrei Lazarev
#
# ...

# %%
for tab in sheet_names:
    print('#  ' + tab + '   #')
    df = pd.read_excel(xls, tab)
    try:
        agg = df[df['Unnamed: 7'] == 'Maria Kuchuk']
        print(agg[['Unnamed: 7']])
    except KeyError:
        print(' no tab HRMS 10')
# Out:
# #  2017   #
# /Users/s_pasiukevich/PycharmProjects/pythonProject4/venv/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#  no tab HRMS 10
# #  Сводная   #
#  no tab HRMS 10
# #  каталог   #
#  no tab HRMS 10
# #  HRMS12   #
#         Unnamed: 7
# 2     Maria Kuchuk
# 819   Maria Kuchuk
# 827   Maria Kuchuk
# 857   Maria Kuchuk
# 930   Maria Kuchuk
# 931   Maria Kuchuk
# 947   Maria Kuchuk
# 954   Maria Kuchuk
# 987   Maria Kuchuk
# 1075  Maria Kuchuk
# 1084  Maria Kuchuk
# 1103  Maria Kuchuk
# 1120  Maria Kuchuk
# 1139  Maria Kuchuk
# 1143  Maria Kuchuk
# 1177  Maria Kuchuk
# 1186  Maria Kuchuk
# 1189  Maria Kuchuk
# 1198  Maria Kuchuk
# 1214  Maria Kuchuk
# 1230  Maria Kuchuk
# 1247  Maria Kuchuk
# 1255  Maria Kuchuk
# 1273  Maria Kuchuk
# 1308  Maria Kuchuk
# 1400  Maria Kuchuk
# 1414  Maria Kuchuk
# 1416  Maria Kuchuk
# 1436  Maria Kuchuk
# 1440  Maria Kuchuk
# ...
